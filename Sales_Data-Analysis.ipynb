# %%
import pandas as pd

df = pd.read_csv("Sales_Data_Analysis.txt")

print(df)

df["Sales"] = df["Quantity"] * df["Price"]

print("Total Sales")
print(df["Sales"].sum())

print("Average Price")
print(df["Price"].mean())

print("Region Wise Sales")
print(df.groupby("Region")["Sales"].sum())

print("Product Wise Sales")
print(df.groupby("Product")["Sales"].sum())
# Out:
#   Customer Product Region  Quantity  Price
# 0     Ravi  Laptop  South         2  50000
# 1    Priya  Mobile  North         1  30000
# 2     Arun  Tablet  South         3  20000
# 3    Divya  Laptop   East         1  50000
# 4    Kumar  Mobile   West         2  30000
# Total Sales
# 300000
# Average Price
# 36000.0
# Region Wise Sales
# Region
# East      50000
# North     30000
# South    160000
# West      60000
# Name: Sales, dtype: int64
# Product Wise Sales
# Product
# Laptop    150000
# Mobile     90000
# Tablet     60000
# Name: Sales, dtype: int64

# %%
import matplotlib.pyplot as plt

df.groupby("Product")["Sales"].sum().plot(kind="bar")

plt.xlabel("Product")
plt.ylabel("Sales")
plt.title("Product Wise Sales")

plt.show()
